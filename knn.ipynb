# %% [markdown]
# # KNN

# %%
import numpy as np
import pandas as pd

# %%
data_train = pd.read_csv('train_data.csv')
data_test = pd.read_csv('test_data.csv')
test_label = pd.read_csv('test_labels.csv')
train_label = pd.read_csv('train_labels.csv')
print(data_train.shape)
print(train_label.shape)
print(data_test.shape)
print(test_label.shape)
data_train
# Out:
# (9999, 182)
# (9999, 1)
# (3499, 182)
# (3499, 1)
#       3.315305053710937386e+02  -1.016679260253906278e+02  \
# 0                  -253.643958                  -9.861246
# 1                  -244.180627                  20.449904
# 2                   -33.216291                -299.499316
# 3                  -234.107520                  56.435944
# 4                  -249.531061                 -25.064967
# ...                        ...                        ...
# 9994                  7.085250                 116.731775
# 9995                260.220557                 172.953296
# 9996               -186.877936                 213.970093
# 9997                -44.020116                -234.359277
# 9998               -229.432947                  87.089581
#
#       -6.824818725585937784e+01  2.334438934326172088e+01  \
# 0                    120.317908                -30.493530
# 1                     60.363599                -14.572710
# 2                    -50.007623                -33.280038
# 3                     59.336731                120.205432
# 4                     54.411749                 -1.585541
# ...                         ...                       ...
# 9994                 147.757092                -37.310080
# 9995                  94.063483                -77.370013
# 9996                 -64.684436               -200.513525
# 9997                 -65.267609                 29.823511
# 9998                  22.712419               -183.395422
#
#       4.275683593750000000e+01  5.451454101562500227e+02  \
# 0                    34.808917                 55.337402
# 1                    27.917200                 11.049553
# 2                  -120.124011               -155.485620
# 3                   -51.716437                -50.278705
# 4                     2.431669                 44.101395
# ...                        ...                       ...
# 9994               -118.628381                -40.717117
# 9995               -218.507837                 15.332564
# 9996                 53.094934                 89.432684
# 9997                 51.730292                -34.177386
# 9998                 84.588800                 47.812936
#
#       -3.343929672241211293e+00  2.413939056396484517e+01  \
# 0                    -39.295972                 55.469849
# 1                    -66.033972                -52.860059
# 2                    109.901624                  2.329393
# 3                    106.853479                -40.157135
# 4                    -19.332103                -22.094594
# ...                         ...                       ...
# 9994                 -19.980168                 21.877707
# 9995                   6.495235                136.456128
# 9996                 -45.044962                157.714709
# 9997                  59.554425                 36.112582
# 9998                  25.986295                298.271582
#
#       -2.981284484863281392e+01  -5.614431762695312500e+01  ...  \
# 0                     31.122858                  10.575929  ...
# 1                   -100.238312                 -87.267426  ...
# 2                     89.663959                 -19.571330  ...
# 3                    -35.407071                  51.014056  ...
# 4                     29.162976                 -39.110214  ...
# ...                         ...                        ...  ...
# 9994                  24.432263                -128.176636  ...
# 9995                  -6.362043                -175.688318  ...
# 9996                 -65.213062                 -83.462225  ...
# 9997                  69.279779                -117.177148  ...
# 9998                 -38.144855                  66.050348  ...
#
#       8.907287597656250000e+00  5.632847785949707031e+00  \
# 0                   -47.961746                -64.050690
# 1                    36.255955                 12.822381
# 2                   -21.239864                 -6.670719
# 3                    23.906511                 57.207561
# 4                   111.341423                 29.836399
# ...                        ...                       ...
# 9994                  3.343780                 -5.479767
# 9995                 -4.933183                 20.385284
# 9996                -29.555853                 42.715584
# 9997                  4.142395                -38.234112
# 9998                 69.739632                 19.383884
#
#       1.972386741638183594e+01  -1.119696855545043945e+00  \
# 0                    34.537666                 -44.639187
# 1                    31.322819                  19.948681
# 2                    19.629095                  24.637486
# 3                  -100.063805                  18.531885
# 4                    66.358124                 -20.698515
# ...                        ...                        ...
# 9994                 13.795774                   9.798167
# 9995                 18.574984                 -32.633507
# 9996                -51.286999                 -26.935350
# 9997                -12.981946                  19.431517
# 9998                -44.984009                   0.583636
#
#       -2.488973236083984375e+01  -1.712128067016601562e+01  \
# 0                     43.801079                  19.922243
# 1                    -62.447662                  -9.979249
# 2                     -9.525990                  12.243141
# 3                    -34.864243                   7.713210
# 4                    -10.836226                  34.525166
# ...                         ...                        ...
# 9994                 -15.761832                  -7.290184
# 9995                  16.644390                   9.941824
# 9996                  -7.716193                 -15.227501
# 9997                  22.129524                 -10.829691
# 9998                 -48.527805                   5.289689
#
#       -1.217892004551045375e+03  3.389006160659384477e+03  \
# 0                   1684.910420                441.884816
# 1                  -1033.552994              -1858.859804
# 2                   4463.370924              -2467.506298
# 3                   1656.632571               4102.648003
# 4                   2800.598206               2991.680505
# ...                         ...                       ...
# 9994                -329.151810              -1408.173707
# 9995                 657.354799               4527.691115
# 9996                -305.238541               1959.029888
# 9997               -4217.041445              -4590.143735
# 9998               -3479.016901               2695.680357
#
#       3.855318474753810733e+03  3.833375510681036758e+03
# 0                 -2439.558239               3384.079258
# 1                  4116.301185               4157.679787
# 2                  2850.364355               4516.757128
# 3                 -4708.921972              -1727.296082
# 4                 -3256.593178              -2540.554969
# ...                        ...                       ...
# 9994               2577.624407               2507.344705
# 9995                 20.121276                730.696706
# 9996               2889.637091               2000.886912
# 9997               3060.574989               4910.300524
# 9998                491.839433               3012.429131
#
# [9999 rows x 182 columns]

# %%
X_test = np.array(data_test)
X_test_std = (X_test - np.mean(X_test,axis=0)) / np.std(X_test,axis=0)
Y_test = np.array(test_label)
X_train = np.array(data_train)
X_train_std = (X_train - np.mean(X_train,axis=0)) / np.std(X_train,axis=0)
Y_train = np.array(train_label)
k_neighbours = [2,5,10,50]
k_accuracy = []


def knn(train_data, train_label, test_sample, k_neighbours, typeofmetric):
    
    distance = pd.DataFrame(data=np.sqrt(((train_data -test_sample)**2 ).sum(axis=1)),columns=['data'])
    
    if(typeofmetric == "norm1"):
        distance = pd.DataFrame(data=((train_data -test_sample)).max(axis=1),columns=['data'])
    if(typeofmetric== "norm2"):
        distance = pd.DataFrame(data=(abs(train_data -test_sample) ).sum(axis=1),columns=['data'])
       
    distance['label'] = train_label
    distance = distance.sort_values(by='data')
    neighbors = distance.iloc[0:k_neighbours,:]
    label = neighbors['label'].value_counts().idxmax()
    return label



def main(X_train, Y_train, X_test, Y_test, typeofmeric):
    for k in k_neighbours:
        cnt = 0
        for idsample in range(X_test.shape[0]):
            label=knn(X_train, Y_train, X_test[idsample], k, typeofmeric)
            if(label == Y_test[idsample]):
                cnt = cnt+1

        k_accuracy.append(cnt/Y_test.shape[0]*100)
        print(f'accuracy for k={k} is {k_accuracy[-1]}!') 

def mainforbestk(X_train, Y_train, X_test, Y_test, typeofmeric, k):
    cnt = 0
    k_accuracy = 0
    for idsample in range(X_test.shape[0]):
        label=knn(X_train, Y_train, X_test[idsample], k, typeofmeric)
        if(label == Y_test[idsample]):
            cnt = cnt+1

    k_accuracy = cnt/Y_test.shape[0]*100
    print(f'accuracy for k={k} is {k_accuracy}!')

# %%
main(X_train, Y_train, X_test, Y_test, 'euclidean')
# Out:
# accuracy for k=2 is 12.832237782223494!
# accuracy for k=5 is 13.889682766504716!
# accuracy for k=10 is 13.43240925978851!
# accuracy for k=50 is 14.004001143183768!

# %% [markdown]
# #### For classification algorithms like KNN, we measure the distances between pairs of samples and these distances are influenced by the measurement units also. For example: Let’s say, we are applying KNN on a data set having 3 features.First feature ranging from 1-10, second from 1-20 and the last one ranging from 1-1000. In this case, most of the clusters will be generated based on the last feature as the difference between 1 to 10 and 1-20 are smaller as compared to 1-1000. To avoid this miss classification, we should normalize the feature variables.If the scale of features is very different then normalization is required. This is because the distance calculation done in KNN uses feature values. When the one feature values are large than other, that feature will dominate the distance hence the outcome of the KNN!
# So as you can see here the accuracy of the classification is very low,Now we do the classification again for standardized data!

# %%
main(X_train_std, Y_train, X_test_std, Y_test, 'euclidean')
# Out:
# accuracy for k=2 is 71.33466704772792!
# accuracy for k=5 is 74.70705915975994!
# accuracy for k=10 is 73.47813661046013!
# accuracy for k=50 is 61.589025435838806!

# %% [markdown]
# ##### Now you see the difference, here the best accuracy is for k=5!
# For very low values and very high values of k, the accuracy comes down.

# %% [markdown]
# ## Norm1

# %%
print("for standardized data we have: ")
mainforbestk(X_train_std, Y_train, X_test_std, Y_test, 'norm1', 5)
print("before standardized data we have: ")
mainforbestk(X_train, Y_train, X_test, Y_test, 'norm1', 5)
# Out:
# for standardized data we have:
# accuracy for k=5 is 49.299799942840814!
# before standardized data we have:
# accuracy for k=5 is 42.955130037153474!

# %% [markdown]
# ## Norm2

# %%
print("for standardized data we have: ")
mainforbestk(X_train_std, Y_train, X_test_std, Y_test, 'norm2', 5)
print("before standardized data we have: ")
mainforbestk(X_train, Y_train, X_test, Y_test, 'norm2', 5)
# Out:
# for standardized data we have:
# accuracy for k=5 is 75.99314089739926!
# before standardized data we have:
# accuracy for k=5 is 38.496713346670475!

# %% [markdown]
# sharare zolghadr(610395109)
